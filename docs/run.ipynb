# %%
l1 = [1,2,3]
l2 = [2,4,6]
d = {'mon':l1, 'tue':l2}
res = d.values()
l1.append(4)
d['tue'].append(8)
print(res)
# Out:
# dict_values([[1, 2, 3, 4], [2, 4, 6, 8]])

# %%
import numpy as np 
x = np.array([
[2, 4, 6, 8],
[3, 6, 9, 12],
[4, 8, 12, 16]
])

a = x[1:, ::-1]
b = x[[False, True, True], :0:-1]
print(a)
print(b)
# Out:
# [[12  9  6]
#  [16 12  8]]
