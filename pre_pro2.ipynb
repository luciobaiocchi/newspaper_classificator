# %%
import numpy as np
import pandas as pd

# %%
dev = pd.read_csv('winter_project_2026/development.csv')
eval = pd.read_csv('winter_project_2026/evaluation.csv')

lab = dev.iloc[:,-1]
dev.drop(['Id'], axis=1, inplace=True)

# %%
title_dup = dev.duplicated(subset=['title'])

duplicates = dev[title_dup]

# %%
index = dev['title'].isin(duplicates['title'])
df_dupl = dev[index].sort_values('title')

# %%
# Out:
#   Cell In[92], line 1
#     dev[devduplicates['title']
#                               ^
# _IncompleteInputError: incomplete input

# %%
# Out:
# np.int64(203722)
